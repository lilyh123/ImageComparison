# %% [markdown]
# <a href="https://colab.research.google.com/github/lilyh123/ImageProcessing/blob/main/measuring_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install image_slicer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import image_slicer
image_slicer.slice('rey_complex.jpg', 9)
image_slicer.slice('drawing1.jpg', 9)
# Out:
# (<Tile #1 - drawing1_01_01.png>,
#  <Tile #2 - drawing1_01_02.png>,
#  <Tile #3 - drawing1_01_03.png>,
#  <Tile #4 - drawing1_02_01.png>,
#  <Tile #5 - drawing1_02_02.png>,
#  <Tile #6 - drawing1_02_03.png>,
#  <Tile #7 - drawing1_03_01.png>,
#  <Tile #8 - drawing1_03_02.png>,
#  <Tile #9 - drawing1_03_03.png>)

# %%
import cv2 # a model of opencv
from google.colab import files # library that allows the user to upload files
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
from PIL import Image

def orb_sim(img1, img2):
  orb = cv2.ORB_create()

  # detect keypoints and descriptors
  keypoint_a, description_a = orb.detectAndCompute(img1, None)
  keypoint_b, description_b = orb.detectAndCompute(img2, None)

  # define the bruteforce matcher object
  bruteforce = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck = True)

  # perform matches
  matches = bruteforce.match(description_a, description_b)
  # look for similar regions with distance < 67 
  similar_regions = [i for i in matches if i.distance < 67]
  if len(matches) == 0:
    return 0
  return len(similar_regions) / len(matches)

# store the similarity values
totalSimilarity = 0

for x in range(1, 4):
  for y in range(1, 4):
    image1 = 'rey_complex_0' + str(x) + '_0' + str(y) + '.png'
    image2 = 'drawing1_0' + str(x) + '_0' + str(y) + '.png'

    rey_complex = cv2.imread(image1, 0)
    drawing = cv2.imread(image2, 0)

    # show the image
    title1 = image1 + ' Image'
    plt.title(title1)
    image = mpimg.imread(image1)
    plt.imshow(image)
    plt.show()
    title2 = image2 + ' Image'
    plt.title(image2)
    image = mpimg.imread(image2)
    plt.imshow(image)
    plt.show()

    # find the similarity value
    orb_similarity = orb_sim(rey_complex, drawing)
    totalSimilarity += orb_similarity
    print("Similarity using ORB is: ", orb_similarity)

print("Average similarity using ORB is: ", totalSimilarity/9)
# Out:
# Similarity using ORB is:  0.8235294117647058
# Similarity using ORB is:  1.0
# Similarity using ORB is:  0.7647058823529411
# Similarity using ORB is:  0.9152542372881356
# Similarity using ORB is:  0.8904109589041096
# Similarity using ORB is:  0.96875
# Similarity using ORB is:  0.8536585365853658
# Similarity using ORB is:  0.85
# Similarity using ORB is:  0.7142857142857143
# Average similarity using ORB is:  0.8645105267978859

# %%
import cv2 # a model of opencv
from google.colab import files # library that allows the user to upload files
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
from PIL import Image

def orb_sim(img1, img2):
  orb = cv2.ORB_create()

  # detect keypoints and descriptors
  keypoint_a, description_a = orb.detectAndCompute(img1, None)
  keypoint_b, description_b = orb.detectAndCompute(img2, None)

  # define the bruteforce matcher object
  bruteforce = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck = True)

  # perform matches
  matches = bruteforce.match(description_a, description_b)

  # look for similar regions with distance < 67 
  similar_regions = [i for i in matches if i.distance < 67]
  if len(matches) == 0:
    return 0
  return len(similar_regions) / len(matches)

image1 = 'rey_complex.jpg'
image2 = 'drawing1.jpg'

rey_complex = cv2.imread(image1, 0)
drawing = cv2.imread(image2, 0)

# show the image
plt.title("Original Image")
image = mpimg.imread(image1)
plt.imshow(image)
plt.show()
plt.title("Drawing1 Image")
image = mpimg.imread(image2)
plt.imshow(image)
plt.show()

orb_similarity = orb_sim(rey_complex, drawing)
print("Similarity using ORB is: ", orb_similarity)
# Out:
# Similarity using ORB is:  0.9278350515463918

# %%
import cv2 # a model of opencv
from google.colab import files # library that allows the user to upload files
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
from PIL import Image

def orb_sim(img1, img2):
  orb = cv2.ORB_create()

  # detect keypoints and descriptors
  keypoint_a, description_a = orb.detectAndCompute(img1, None)
  keypoint_b, description_b = orb.detectAndCompute(img2, None)

  # define the bruteforce matcher object
  bruteforce = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck = True)

  # perform matches
  matches = bruteforce.match(description_a, description_b)
  
  # look for similar regions with distance < 67 
  similar_regions = [i for i in matches if i.distance < 67]
  if len(matches) == 0:
    return 0
  return len(similar_regions) / len(matches)

image1 = 'rey_complex.jpg'
image2 = 'drawing2.jpg'

rey_complex = cv2.imread(image1, 0)
drawing = cv2.imread(image2, 0)

# show the image
plt.title("Original Image")
image = mpimg.imread(image1)
plt.imshow(image)
plt.show()
plt.title("Drawing2 Image")
image = mpimg.imread(image2)
plt.imshow(image)
plt.show()

orb_similarity = orb_sim(rey_complex, drawing)
print("Similarity using ORB is: ", orb_similarity)
# Out:
# Similarity using ORB is:  0.7910447761194029

# %%
import cv2 # a model of opencv
from google.colab import files # library that allows the user to upload files
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
from PIL import Image

def orb_sim(img1, img2):
  orb = cv2.ORB_create()

  # detect keypoints and descriptors
  keypoint_a, description_a = orb.detectAndCompute(img1, None)
  keypoint_b, description_b = orb.detectAndCompute(img2, None)

  # define the bruteforce matcher object
  bruteforce = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck = True)

  # perform matches
  matches = bruteforce.match(description_a, description_b)
  
  # look for similar regions with distance < 67 
  similar_regions = [i for i in matches if i.distance < 67]
  if len(matches) == 0:
    return 0
  return len(similar_regions) / len(matches)

image1 = 'rey_complex.jpg'
image2 = 'drawing3.jpg'

rey_complex = cv2.imread(image1, 0)
drawing = cv2.imread(image2, 0)

# show the image
plt.title("Original Image")
image = mpimg.imread(image1)
plt.imshow(image)
plt.show()
plt.title("Drawing3 Image")
image = mpimg.imread(image2)
plt.imshow(image)
plt.show()

orb_similarity = orb_sim(rey_complex, drawing)
print("Similarity using ORB is: ", orb_similarity)
# Out:
# Similarity using ORB is:  0.9230769230769231

# %%
import cv2 # a model of opencv
from google.colab import files # library that allows the user to upload files
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
from PIL import Image

def orb_sim(img1, img2):
  orb = cv2.ORB_create()

  # detect keypoints and descriptors
  keypoint_a, description_a = orb.detectAndCompute(img1, None)
  keypoint_b, description_b = orb.detectAndCompute(img2, None)

  # define the bruteforce matcher object
  bruteforce = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck = True)

  # perform matches
  matches = bruteforce.match(description_a, description_b)
  
  # look for similar regions with distance < 67 
  similar_regions = [i for i in matches if i.distance < 67]
  if len(matches) == 0:
    return 0
  return len(similar_regions) / len(matches)

image1 = 'rey_complex.jpg'
image2 = 'drawing4.jpg'

rey_complex = cv2.imread(image1, 0)
drawing = cv2.imread(image2, 0)

# show the image
plt.title("Original Image")
image = mpimg.imread(image1)
plt.imshow(image)
plt.show()
plt.title("Drawing4 Image")
image = mpimg.imread(image2)
plt.imshow(image)
plt.show()

orb_similarity = orb_sim(rey_complex, drawing)
print("Similarity using ORB is: ", orb_similarity)
# Out:
# Similarity using ORB is:  0.9587628865979382

# %%
import cv2 # a model of opencv
from google.colab import files # library that allows the user to upload files
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
from PIL import Image

def orb_sim(img1, img2):
  orb = cv2.ORB_create()

  # detect keypoints and descriptors
  keypoint_a, description_a = orb.detectAndCompute(img1, None)
  keypoint_b, description_b = orb.detectAndCompute(img2, None)

  # define the bruteforce matcher object
  bruteforce = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck = True)

  # perform matches
  matches = bruteforce.match(description_a, description_b)
  
  # look for similar regions with distance < 67 
  similar_regions = [i for i in matches if i.distance < 67]
  if len(matches) == 0:
    return 0
  return len(similar_regions) / len(matches)

image1 = 'rey_complex.jpg'
image2 = 'drawing5.jpg'

rey_complex = cv2.imread(image1, 0)
drawing = cv2.imread(image2, 0)

# show the image
plt.title("Original Image")
image = mpimg.imread(image1)
plt.imshow(image)
plt.show()
plt.title("Drawing5 Image")
image = mpimg.imread(image2)
plt.imshow(image)
plt.show()

orb_similarity = orb_sim(rey_complex, drawing)
print("Similarity using ORB is: ", orb_similarity)
# Out:
# Similarity using ORB is:  0.9411764705882353

# %%
import cv2 as cv
import numpy as np
from google.colab.patches import cv2_imshow

img = cv.imread('drawing5.jpg', cv.IMREAD_GRAYSCALE)
assert img is not None, "file could not be read, check with os.path.exists()"
kernel = np.ones((5,5),np.uint8)
erosion = cv.erode(img,kernel,iterations = 1)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=542x374 at 0x7F38CF943040>

# %% [markdown]
# Reference:
# *   https://github.com/bnsreenu/python_for_microscopists/blob/master/191_measure_img_similarity.py
